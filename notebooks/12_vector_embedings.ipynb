# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language",
    "The capital of France is Paris",
    "The Great Wall of China is visible from space",
    "The human brain has approximately 86 billion neurons",
    "The Earth revolves around the Sun"
]

# %%
from langchain_openai import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(model = "text-embedding-3-small")

# %%
vector=embeddings.embed_documents(documents)
print(len(vector))
print(len(vector[0]))
# Out:
# 9
# 1536

# %% [markdown]
# ### store vectores embeddings in vector db

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query = "What is machine learning?"
result = vector_store.similarity_search(query)
result
# Out:
# [Document(id='e3f40f1b-708a-4476-b2af-0a29321350ef', metadata={}, page_content='Machine learning is a subset of artificial intelligence'),
#  Document(id='04ce781a-a89c-4c25-b03b-424798624c51', metadata={}, page_content='Deep learning uses neural networks with multiple layers'),
#  Document(id='e45a9564-9c1b-4a30-983d-6ea387da52ad', metadata={}, page_content='AI models can understand and generate human language'),
#  Document(id='070bdd48-9340-4b8d-9ff3-9688b9e8af9c', metadata={}, page_content='Python is a programming language popular for data science')]
