# %%
from dotenv import load_dotenv
load_dotenv() # loads .env file
# Out:
# True

# %%
import os

api_key = os.getenv("GOOGLE_API_KEY")

print(api_key)  # just to test our variable works here also.

# %% [markdown]
# connect with OpenAI model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
result = llm.invoke("What is ML ?")
print(result.content)
# Out:
# content='ML stands for Machine Learning, which is a subset of artificial intelligence (AI) that focuses on the development of algorithms that enable computers to learn from and make predictions or decisions based on data. Instead of being explicitly programmed for every task, machine learning algorithms use statistical techniques to identify patterns and trends in data, allowing systems to improve their performance over time as they are exposed to more data.\n\nMachine learning can be categorized into several types:\n\n1. **Supervised Learning**: The model is trained on a labeled dataset, which means the input data is paired with the correct output. The goal is to learn a function that maps inputs to the correct output. Common applications include classification and regression tasks.\n\n2. **Unsupervised Learning**: The model is trained on data without labeled outputs. The goal is to identify underlying patterns or groupings in the data. Techniques include clustering and dimensionali
# ...

# %%
print(llm.invoke("winner of ipl 2020 ?"))
# Out:
# content='The winner of IPL 2020 was the Mumbai Indians. They secured their fifth title by defeating the Delhi Capitals in the final, which was held on November 10, 2020.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 15, 'total_tokens': 53, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e155db4643', 'id': 'chatcmpl-DRxOSqiYvKbgAhybgCEG6pD90Y1S9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d675b-69d8-7091-948b-fb1fd953e64e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 38, 'total_tokens': 53, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 're
# ...

# %% [markdown]
# connect with google Geminin Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res =llm.invoke("what is genAI in short?")
print(res.content)
# Out:
# GenAI stands for **Generative Artificial Intelligence**.
#
# In short, it's AI that can **create new content** (like text, images, music, code) rather than just analyzing or classifying existing data.

# %% [markdown]
# connect with antropic

# %%
from langchain_anthropic import ChatAnthropic

# %%
llm = ChatAnthropic(
    model="claude-sonnet-4-6",
  max_tokens=1024,
)

res = llm.invoke("Explain machine learning in one line")
print(res.content)
# Out:
# **Machine learning is a type of AI where computers learn patterns from data to make predictions or decisions without being explicitly programmed.**

# %%
res = llm.invoke("give me python code to check number is even or not")
print(res.content)
# Out:
# ## Check Even or Odd Number in Python
#
# ### Simple Example
# ```python
# number = int(input("Enter a number: "))
#
# if number % 2 == 0:
#     print(f"{number} is Even")
# else:
#     print(f"{number} is Odd")
# ```
#
# ---
#
# ### Using a Function
# ```python
# def is_even(number):
#     """Check if a number is even or odd."""
#     if number % 2 == 0:
#         return True
#     else:
#         return False
#
# # Get input from user
# number = int(input("Enter a number: "))
#
# if is_even(number):
#     print(f"{number} is Even")
# else:
#     print(f"{number} is Odd")
# ```
#
# ---
#
# ### One-Line Solution
# ```python
# number = int(input("Enter a number: "))
# print("Even" if number % 2 == 0 else "Odd")
# ```
#
# ---
#
# ### Output
# ```
# Enter a number: 10
# 10 is Even
#
# Enter a number: 7
# 7 is Odd
# ```
#
# ---
#
# ## Explanation
#
# | Operator | Description | Example |
# |----------|-------------|---------|
# | `%` | Modulus (remainder) | `10 % 2 = 0` → Even |
# ...

# %% [markdown]
# ## Static Prompts

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
prompts=[
    ("system", "You are a Python developer."),
    ("user","How to sort the array.")
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# In Python, you can sort an array (which is often represented as a list) using various methods. Here are some common ways to do that:
#
# ### 1. Using the `sort()` method
#
# The `sort()` method sorts a list in place, meaning that it modifies the original list and does not return a new list.
#
# ```python
# # Example list
# arr = [5, 2, 9, 1, 5, 6]
#
# # Sort the list in ascending order
# arr.sort()
#
# print(arr)  # Output: [1, 2, 5, 5, 6, 9]
# ```
#
# ### 2. Using the `sorted()` function
#
# The `sorted()` function creates a new sorted list from the elements of any iterable (such as lists, tuples, etc.).
#
# ```python
# # Example list
# arr = [5, 2, 9, 1, 5, 6]
#
# # Sort the list in ascending order and return a new list
# sorted_arr = sorted(arr)
#
# print(sorted_arr)  # Output: [1, 2, 5, 5, 6, 9]
# print(arr)  # Original list remains unchanged: [5, 2, 9, 1, 5, 6]
# ```
#
# ### 3. Sorting in descending order
#
# ...

# %%
prompt=[
    ("system", "You are a java developer."),
    ("user","How to sort the array.")
]
res = llm.invoke(prompt)
print(res.content)
# Out:
# In Java, there are several ways to sort an array. Below are some common methods you can use:
#
# ### 1. Using `Arrays.sort()`
#
# The simplest way to sort an array is to use the `Arrays.sort()` method from the `java.util.Arrays` class. This method sorts the array in place.
#
# #### Example: Sorting an Integer Array
# ```java
# import java.util.Arrays;
#
# public class SortExample {
#     public static void main(String[] args) {
#         int[] numbers = {5, 2, 8, 1, 3};
#
#         // Sorting the array
#         Arrays.sort(numbers);
#
#         System.out.println("Sorted array: " + Arrays.toString(numbers));
#     }
# }
# ```
#
# #### Example: Sorting a String Array
# ```java
# import java.util.Arrays;
#
# public class SortExample {
#     public static void main(String[] args) {
#         String[] fruits = {"Banana", "Apple", "Grapes", "Orange"};
#
#         // Sorting the array
#         Arrays.sort(fruits);
#
# ...
